# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("student_performance.csv")

# %%
df
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# ...

# %%
df.head(10)
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
# 5           6                     13.4                   65.1
# 6           7                     26.1                   81.8
# 7           8                     20.4                  100.0
# 8           9                     11.7                  100.0
# 9          10                     18.8                   67.6
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A
# ...

# %%
df.tail()
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 999995                  4.8        100.0     A
# 999996                  6.7         88.3     A
# 999997                  5.8         87.9     A
# 999998                  5.3        100.0     A
# 999999                  4.1        100.0     A

# %%
df.sample(6)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 929861      929862                      8.8                   92.5
# 34102        34103                     15.8                   82.2
# 568409      568410                      0.5                   95.0
# 244250      244251                     16.4                   99.4
# 500005      500006                     11.6                   84.6
# 875110      875111                     11.2                   76.0
#
#         class_participation  total_score grade
# 929861                  7.5         65.6     C
# 34102                   5.4         89.6     A
# 568409                  4.5         60.4     C
# 244250                  5.6         79.6     B
# 500005                  1.3         87.8     A
# 875110                  8.2         82.1     B

# %%
df.isnull().sum()
# Out:
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   student_id               1000000 non-null  int64
#  1   weekly_self_study_hours  1000000 non-null  float64
#  2   attendance_percentage    1000000 non-null  float64
#  3   class_participation      1000000 non-null  float64
#  4   total_score              1000000 non-null  float64
#  5   grade                    1000000 non-null  str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 46.7 MB

# %%
df.describe()
# Out:
#            student_id  weekly_self_study_hours  attendance_percentage  \
# count  1000000.000000           1000000.000000         1000000.000000
# mean    500000.500000                15.029127              84.711046
# std     288675.278932                 6.899431               9.424143
# min          1.000000                 0.000000              50.000000
# 25%     250000.750000                10.300000              78.300000
# 50%     500000.500000                15.000000              85.000000
# 75%     750000.250000                19.700000              91.800000
# max    1000000.000000                40.000000             100.000000
#
#        class_participation     total_score
# count       1000000.000000  1000000.000000
# mean              5.985203       84.283845
# std               1.956421       15.432969
# min               0.000000        9.400000
# 25%               4.700000       73.900000
# 50%               6.000000       87.500000
# ...

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 1000000
# Columns : 6

# %%
df.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='str')

# %%
df.dtypes
# Out:
# student_id                   int64
# weekly_self_study_hours    float64
# attendance_percentage      float64
# class_participation        float64
# total_score                float64
# grade                          str
# dtype: object

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="grade", data=df)
plt.title("Distribution of Grades")
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.savefig("Grade Distribution .png",dpi=150)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(df["attendance_percentage"], bins=20, kde=True)
plt.title("Attendance Distribution")
plt.savefig("Attendance Distribution.png",dpi=150)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(df["weekly_self_study_hours"], bins=20, kde=True)
plt.title("Weekly Self Study Hours")
plt.savefig("Weekly Self Study Hours.png",dpi=160)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(df["total_score"], bins=20, kde=True)
plt.title("Total Score Distribution")
plt.savefig("Total Score Distribution.png",dpi=150)
plt.show()

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#                          student_id  weekly_self_study_hours  \
# student_id                 1.000000                -0.001607
# weekly_self_study_hours   -0.001607                 1.000000
# attendance_percentage     -0.000353                -0.001008
# class_participation        0.001277                 0.001244
# total_score               -0.000492                 0.812241
#
#                          attendance_percentage  class_participation  \
# student_id                           -0.000353             0.001277
# weekly_self_study_hours              -0.001008             0.001244
# attendance_percentage                 1.000000            -0.000043
# class_participation                  -0.000043             1.000000
# total_score                          -0.001014             0.000684
#
#                          total_score
# student_id                 -0.000492
# weekly_self_study_hours     0.812241
# attendance_percentage      -0.001014
# ...

# %%
plt.figure(figsize=(7,5))
sns.boxplot(
    x="grade",
    y="attendance_percentage",
    data=df
)
plt.title("Attendance vs Grade")
plt.savefig("Attendance vs Grade.png",dpi=150)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(
    x="grade",
    y="weekly_self_study_hours",
    data=df
)
plt.title("Study Hours vs Grade")
plt.savefig("Study Hours vs Grade.png",dpi=150)
plt.show()

# %%
df.to_csv("clean_student_performance.csv", index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)
import joblib

# %%
le = LabelEncoder()
df["grade"] = le.fit_transform(df["grade"])
print(dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# {'A': np.int64(0), 'B': np.int64(1), 'C': np.int64(2), 'D': np.int64(3), 'F': np.int64(4)}

# %%
X = df.drop(columns=["student_id", "grade", "total_score"])
y = df["grade"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
print("Logistic Regression Accuracy:", accuracy_score(y_test, lr_pred))
# Out:
# Logistic Regression Accuracy: 0.695755

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, dt_pred))
# Out:
# Decision Tree Accuracy: 0.608735

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.644555

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
})
importance = importance.sort_values(
    by="Importance",
    ascending=False
)
print(importance)
# Out:
#                    Feature  Importance
# 0  weekly_self_study_hours    0.499584
# 1    attendance_percentage    0.346106
# 2      class_participation    0.154309

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    data=importance,
    x="Importance",
    y="Feature"
)
plt.title("Feature Importance")
plt.savefig("Feature Importance.png",dpi=150)
plt.show()

# %%
joblib.dump(rf, "student_model.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(le, "label_encoder.pkl")
print("Model saved successfully!")
# Out:
# Model saved successfully!
